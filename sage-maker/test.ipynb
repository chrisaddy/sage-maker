# %%
import pytorch_lightning as zeus
from sages import GAN
import os
import torch
import torchvision
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-894f378cdda7> in <module>
#       1 import pytorch_lightning as zeus
# ----> 2 from sages import GAN
#       3 import os
#       4 import torch
#       5 import torchvision
#
# ~/dev/sage-maker/sage-maker/sages.py in <module>
#       2 import os
#       3 from PIL import Image
# ----> 4 from alive_progress import alive_bar
#       5 from pathlib import Path
#       6 import multiprocessing
#
# ModuleNotFoundError: No module named 'alive_progress'

# %%
model = GAN.load_from_checkpoint("17/ea703a2a3f434757896f28de529d6694/checkpoints/epoch=6-step=1938.ckpt")

# %%
model.eval()

# %%
z = model.validation_z.type_as(model.generator.model[0].weight)

# %%
grid = torchvision.utils.make_grid(model(z))

# %%
torchvision.transforms.ToPILImage()(grid)

# %%
grid.size()
# Out:
# torch.Size([3, 260, 2066])
